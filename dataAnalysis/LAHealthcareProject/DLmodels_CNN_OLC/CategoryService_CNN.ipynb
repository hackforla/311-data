# %% [markdown]
# ### Categories of Services Shortage Classification (CNN Multi-Class)
#
# 1. Data was first pre-processed and load the final version of la_facility_mua.csv here
#
# 2. Since feature engineering has been done, a few touch-ups before training:
#
# a) **Feature Mapping,**
#
# b) **Dropping useless variables,**
#
# c) **Datetime conversion,**
#
# d) **Days Diff**
#
# 3. We have **3 main types of Services (Target variable: Category Service)**
#
# a) **Health and Mental Health**
#
# b) **Social Services**
#
# c) **Public Safety**
#
# 4. Data was split into Train and Validation
#
# 5. Model: **CNN (Library: TensorFlow.Keras)**

# %%
import os
os.environ['PYTHONHASHSEED']='0'

# %%
import pandas as pd
import numpy as np
import random as rn
# Deep Learning Libraries
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.layers import Conv1D,MaxPool1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras import callbacks
from tensorflow.keras.models import load_model
import tensorflow as tf
np.random.seed(37)
rn.seed(42)
tf.random.set_seed(42)
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.gridspec as gridspec
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import auc,roc_auc_score
from catboost import CatBoostClassifier,Pool, cv
from sklearn.preprocessing import LabelEncoder
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_curve, auc, classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, cross_val_score, KFold, StratifiedKFold

la_facility_mua = pd.read_csv('../input/la-final-data-2/la_facility_mua.csv')

# %%
la_facility_mua.head()
# Out:
#   source             cat1                          cat2  \
# 0    211  Social Services  Children and Family Services
# 1    211  Social Services  Children and Family Services
# 2    211  Social Services  Children and Family Services
# 3    211  Social Services  Children and Family Services
# 4    211  Social Services  Children and Family Services
#
#                    org_name  \
# 0  neweconomicsforwomen.org
# 1  neweconomicsforwomen.org
# 2  neweconomicsforwomen.org
# 3  neweconomicsforwomen.org
# 4  neweconomicsforwomen.org
#
#                                                 Name           addrln1  \
# 0  New Economics For Women - Familysource Center ...  501 S. Bixel St.
# 1  New Economics For Women - Familysource Center ...  501 S. Bixel St.
# 2  New Economics For Women - Familysource Center ...  501 S. Bixel St.
# 3  New Economics For Women - Familysource Center ...  501 S. Bixel St.
# 4  New Economics For Women - Familysource Center ...  501 S. Bixel St.
#
#           city state  post_id  \
# 0  Los Angeles    CA    56652
# 1  Los Angeles    CA    56652
# 2  Los Angeles    CA    56652
# 3  Los Angeles    CA    56652
# 4  Los Angeles    CA    56652
#
#                                          description  ...  \
# 0  The agency is an economic development organiza...  ...
# 1  The agency is an economic development organiza...  ...
# 2  The agency is an economic development organiza...  ...
# 3  The agency is an economic development organiza...  ...
# 4  The agency is an economic development organiza...  ...
#
#         facility_address_1 MUA_RuralStatus  MUA_Designated_Time  \
# 0   415 South Union Avenue           Urban         1.067990e+12
# 1          600 St Paul Ave           Urban         7.686144e+11
# 2            1125 W 6th St           Urban         7.686144e+11
# 3  1225 Wilshire Boulevard           Urban         7.686144e+11
# 4       1127 Wilshire Blvd           Urban         7.686144e+11
#
#    MUA_Designated_Date                   MUA_MSSA_Name_1  MUA_Updated_Time  \
# 0           2003-11-05  MSSA 78.2b (Pico Union/Westlake)      1.067990e+12
# 1           1994-05-11             Westlake Service Area      1.005782e+12
# 2           1994-05-11             Westlake Service Area      1.005782e+12
# 3           1994-05-11             Westlake Service Area      1.005782e+12
# 4           1994-05-11             Westlake Service Area      1.005782e+12
#
#   MUA_Updated_Date MUA_Poverty MUA_Score  MUA_Pct_100Poverty
# 0       2003-11-05    157757.0      51.0                 0.0
# 1       2001-11-15         0.0      60.1                 0.0
# 2       2001-11-15         0.0      60.1                 0.0
# 3       2001-11-15         0.0      60.1                 0.0
# 4       2001-11-15         0.0      60.1                 0.0
#
# [5 rows x 32 columns]

# %%
la_facility_mua.rename({'cat1': 'Category Service'}, axis=1, inplace=True)

# %% [markdown]
# #### We will use 'Service Category' as our target variable

# %%
la_facility_mua['Category Service'].value_counts().sort_values(ascending=False)
# Out:
# Health and Mental Health    4858
# Social Services             4330
# Public Safety               1317
# Name: Category Service, dtype: int64

# %%
la_facility_mua['Category Service']=la_facility_mua['Category Service'].map({
'Health and Mental Health':0,
'Social Services':1,
'Public Safety':2
})
la_facility_mua['Category Service']=la_facility_mua['Category Service'].astype('int32')

# %%
la_facility_mua['facility_er_service'] = la_facility_mua['facility_er_service'].map({
'Not Applicable':'Not Applicable',
'None':'Not Applicable',
'Emergency - Basic':'Emergency',
'Emergency - Comprehensive':'Emergency',
'Emergency - Standby':'Emergency'
})

# %%
la_facility_mua['MUA_Poverty']=la_facility_mua['MUA_Poverty'].map({
157757.0:2,
129447.0:1,
0.0:0,
})

# %%
la_facility_mua['MUA_Designated_Date'] = pd.to_datetime(la_facility_mua['MUA_Designated_Date']) 
la_facility_mua['MUA_Updated_Date'] = pd.to_datetime(la_facility_mua['MUA_Updated_Date']) 
la_facility_mua['Date Difference'] = la_facility_mua['MUA_Updated_Date']-la_facility_mua['MUA_Designated_Date']

# %%
def ddiff2days(ddiff):
    if not pd.isnull(ddiff):
        return pd.Timedelta.total_seconds(ddiff)/(24.*3600)
    else:
        return np.NaN

# %%
la_facility_mua['Date Difference']=la_facility_mua['Date Difference'].apply(ddiff2days)
la_facility_mua['Date Difference']=la_facility_mua['Date Difference'].astype('int32')

# %%
la_facility_mua['design_year'] = (la_facility_mua['MUA_Designated_Date'].dt.year).astype('int32')
la_facility_mua['design_month'] = (la_facility_mua['MUA_Designated_Date'].dt.month).astype('int32')
la_facility_mua['design_week'] = (la_facility_mua['MUA_Designated_Date'].dt.week).astype('int32')
la_facility_mua['design_dow'] = (la_facility_mua['MUA_Designated_Date'].dt.dayofweek).astype('int32')

la_facility_mua['update_year'] = (la_facility_mua['MUA_Updated_Date'].dt.year).astype('int32')
la_facility_mua['update_month'] = (la_facility_mua['MUA_Updated_Date'].dt.month).astype('int32')
la_facility_mua['update_week'] = (la_facility_mua['MUA_Updated_Date'].dt.week).astype('int32')
la_facility_mua['update_dow'] = (la_facility_mua['MUA_Updated_Date'].dt.dayofweek).astype('int32')

# %%
la_facility_mua.drop([
                      'MUA_Designated_Date', 'MUA_Updated_Date',                     
 ], axis=1, inplace=True)

# %%
cols = [c for c in la_facility_mua.columns if la_facility_mua[c].dtypes=='object']
for c in cols:
    le = LabelEncoder()
    la_facility_mua[c] = (le.fit_transform(la_facility_mua[c])).astype('int32')

# %%
X = la_facility_mua.drop(labels=['Category Service'], axis=1)
y = la_facility_mua['Category Service']

from sklearn.model_selection import train_test_split
X_train, X_cv, y_train, y_cv = train_test_split(X, y, test_size=0.25, random_state=tf.random.set_seed(42))

# %%
X_train = X_train.to_numpy()
X_cv = X_cv.to_numpy()

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_cv = X_cv.reshape(X_cv.shape[0],X_cv.shape[1],1)

# %%
# Convolutional Neural Networks (CNN)
epoch = 80
model = Sequential()
model.add(Conv1D(40,2,activation='relu',kernel_initializer='he_normal',input_shape = X_train[0].shape))
model.add(Conv1D(100,2,activation='relu', kernel_initializer='he_normal'))
model.add(Conv1D(60,2,activation='relu', kernel_initializer='he_normal'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(50,activation='relu', kernel_initializer='he_normal'))
model.add(Dense(3,activation='softmax'))

# %%
model.compile(optimizer=Adam(lr=0.001), loss = 'sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# %%
earlystop = EarlyStopping(patience=6) 
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.96, 
                                            min_lr=0.00001)
checkpointer = ModelCheckpoint(filepath='CNN_ServiceCategory', monitor='val_accuracy', verbose=1, 
                save_best_only=True, mode='max', period=1)
callbacks = [#earlystop, 
             learning_rate_reduction, checkpointer
            ]

# %%
history = model.fit(X_train, y_train, epochs=epoch, 
                    validation_data=(X_cv, y_cv), 
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Train on 7878 samples, validate on 2627 samples
# Epoch 1/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 1.0319 - accuracy: 0.4613
# Epoch 00001: val_accuracy improved from -inf to 0.56909, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 9s 1ms/sample - loss: 1.0315 - accuracy: 0.4614 - val_loss: 0.9235 - val_accuracy: 0.5691
# Epoch 2/80
# 7872/7878 [============================>.] - ETA: 0s - loss: 0.7792 - accuracy: 0.6199
# Epoch 00002: val_accuracy improved from 0.56909 to 0.74077, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 867us/sample - loss: 0.7789 - accuracy: 0.6201 - val_loss: 0.5770 - val_accuracy: 0.7408
# Epoch 3/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.4193 - accuracy: 0.7967
# Epoch 00003: val_accuracy improved from 0.74077 to 0.90978, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 857us/sample - loss: 0.4178 - accuracy: 0.7977 - val_loss: 0.2334 - val_accuracy: 0.9098
# Epoch 4/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.3325 - accuracy: 0.8395
# Epoch 00004: val_accuracy did not improve from 0.90978
# 7878/7878 [==============================] - 4s 498us/sample - loss: 0.3328 - accuracy: 0.8393 - val_loss: 0.2932 - val_accuracy: 0.8595
# Epoch 5/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.2728 - accuracy: 0.8609
# Epoch 00005: val_accuracy did not improve from 0.90978
# 7878/7878 [==============================] - 4s 506us/sample - loss: 0.2720 - accuracy: 0.8613 - val_loss: 0.1733 - val_accuracy: 0.9067
# Epoch 6/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.2585 - accuracy: 0.8703
# Epoch 00006: val_accuracy improved from 0.90978 to 0.91093, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 856us/sample - loss: 0.2581 - accuracy: 0.8704 - val_loss: 0.2095 - val_accuracy: 0.9109
# Epoch 7/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.2292 - accuracy: 0.8842
# Epoch 00007: val_accuracy did not improve from 0.91093
# 7878/7878 [==============================] - 4s 490us/sample - loss: 0.2292 - accuracy: 0.8840 - val_loss: 0.2242 - val_accuracy: 0.9033
# Epoch 8/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.2025 - accuracy: 0.8975
# Epoch 00008: val_accuracy improved from 0.91093 to 0.92196, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 6s 824us/sample - loss: 0.2024 - accuracy: 0.8976 - val_loss: 0.1525 - val_accuracy: 0.9220
# Epoch 9/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1960 - accuracy: 0.9028
# Epoch 00009: val_accuracy did not improve from 0.92196
# 7878/7878 [==============================] - 4s 485us/sample - loss: 0.1962 - accuracy: 0.9026 - val_loss: 0.1457 - val_accuracy: 0.9159
# Epoch 10/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.1847 - accuracy: 0.9048
# Epoch 00010: val_accuracy improved from 0.92196 to 0.92501, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 856us/sample - loss: 0.1855 - accuracy: 0.9043 - val_loss: 0.1391 - val_accuracy: 0.9250
# Epoch 11/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.1804 - accuracy: 0.9092
# Epoch 00011: val_accuracy improved from 0.92501 to 0.93795, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 829us/sample - loss: 0.1797 - accuracy: 0.9095 - val_loss: 0.1311 - val_accuracy: 0.9380
# Epoch 12/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.1708 - accuracy: 0.9127
# Epoch 00012: val_accuracy did not improve from 0.93795
# 7878/7878 [==============================] - 4s 538us/sample - loss: 0.1708 - accuracy: 0.9125 - val_loss: 0.1422 - val_accuracy: 0.9307
# Epoch 13/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1603 - accuracy: 0.9184
# Epoch 00013: val_accuracy did not improve from 0.93795
# 7878/7878 [==============================] - 4s 510us/sample - loss: 0.1600 - accuracy: 0.9185 - val_loss: 0.1416 - val_accuracy: 0.9277
# Epoch 14/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.1675 - accuracy: 0.9151
# Epoch 00014: val_accuracy improved from 0.93795 to 0.94062, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 852us/sample - loss: 0.1670 - accuracy: 0.9152 - val_loss: 0.1306 - val_accuracy: 0.9406
# Epoch 15/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1654 - accuracy: 0.9196
# Epoch 00015: val_accuracy did not improve from 0.94062
# 7878/7878 [==============================] - 4s 486us/sample - loss: 0.1651 - accuracy: 0.9198 - val_loss: 0.1278 - val_accuracy: 0.9380
# Epoch 16/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1549 - accuracy: 0.9226
# Epoch 00016: val_accuracy improved from 0.94062 to 0.94785, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 6s 823us/sample - loss: 0.1547 - accuracy: 0.9228 - val_loss: 0.1225 - val_accuracy: 0.9478
# Epoch 17/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1532 - accuracy: 0.9200
# Epoch 00017: val_accuracy did not improve from 0.94785
# 7878/7878 [==============================] - 4s 484us/sample - loss: 0.1527 - accuracy: 0.9204 - val_loss: 0.1464 - val_accuracy: 0.9155
# Epoch 18/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.1576 - accuracy: 0.9203
# Epoch 00018: val_accuracy improved from 0.94785 to 0.95204, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 852us/sample - loss: 0.1569 - accuracy: 0.9208 - val_loss: 0.1194 - val_accuracy: 0.9520
# Epoch 19/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1449 - accuracy: 0.9270
# Epoch 00019: val_accuracy did not improve from 0.95204
# 7878/7878 [==============================] - 4s 486us/sample - loss: 0.1446 - accuracy: 0.9273 - val_loss: 0.1211 - val_accuracy: 0.9467
# Epoch 20/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1569 - accuracy: 0.9251
# Epoch 00020: val_accuracy did not improve from 0.95204
# 7878/7878 [==============================] - 4s 491us/sample - loss: 0.1564 - accuracy: 0.9254 - val_loss: 0.1094 - val_accuracy: 0.9406
# Epoch 21/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.1412 - accuracy: 0.9321
# Epoch 00021: val_accuracy improved from 0.95204 to 0.96041, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 832us/sample - loss: 0.1408 - accuracy: 0.9323 - val_loss: 0.0960 - val_accuracy: 0.9604
# Epoch 22/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1427 - accuracy: 0.9291
# Epoch 00022: val_accuracy improved from 0.96041 to 0.96536, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 853us/sample - loss: 0.1443 - accuracy: 0.9288 - val_loss: 0.0925 - val_accuracy: 0.9654
# Epoch 23/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1574 - accuracy: 0.9277
# Epoch 00023: val_accuracy did not improve from 0.96536
# 7878/7878 [==============================] - 4s 492us/sample - loss: 0.1572 - accuracy: 0.9276 - val_loss: 0.1121 - val_accuracy: 0.9520
# Epoch 24/80
# 7872/7878 [============================>.] - ETA: 0s - loss: 0.1442 - accuracy: 0.9275
# Epoch 00024: val_accuracy did not improve from 0.96536
# 7878/7878 [==============================] - 4s 527us/sample - loss: 0.1443 - accuracy: 0.9274 - val_loss: 0.1317 - val_accuracy: 0.9399
# Epoch 25/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.1519 - accuracy: 0.9266
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0009600000455975532.
#
# Epoch 00025: val_accuracy did not improve from 0.96536
# 7878/7878 [==============================] - 4s 529us/sample - loss: 0.1519 - accuracy: 0.9268 - val_loss: 0.0969 - val_accuracy: 0.9635
# Epoch 26/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1414 - accuracy: 0.9318
# Epoch 00026: val_accuracy did not improve from 0.96536
# 7878/7878 [==============================] - 4s 500us/sample - loss: 0.1412 - accuracy: 0.9321 - val_loss: 0.1184 - val_accuracy: 0.9456
# Epoch 27/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1348 - accuracy: 0.9365
# Epoch 00027: val_accuracy did not improve from 0.96536
# 7878/7878 [==============================] - 4s 488us/sample - loss: 0.1345 - accuracy: 0.9365 - val_loss: 0.0890 - val_accuracy: 0.9642
# Epoch 28/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.1262 - accuracy: 0.9387
# Epoch 00028: val_accuracy improved from 0.96536 to 0.96802, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 847us/sample - loss: 0.1256 - accuracy: 0.9391 - val_loss: 0.0890 - val_accuracy: 0.9680
# Epoch 29/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1155 - accuracy: 0.9474
# Epoch 00029: val_accuracy did not improve from 0.96802
# 7878/7878 [==============================] - 4s 487us/sample - loss: 0.1156 - accuracy: 0.9474 - val_loss: 0.0885 - val_accuracy: 0.9657
# Epoch 30/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.1234 - accuracy: 0.9424
# Epoch 00030: val_accuracy did not improve from 0.96802
# 7878/7878 [==============================] - 4s 494us/sample - loss: 0.1233 - accuracy: 0.9425 - val_loss: 0.0780 - val_accuracy: 0.9680
# Epoch 31/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1203 - accuracy: 0.9455
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0009216000325977802.
#
# Epoch 00031: val_accuracy did not improve from 0.96802
# 7878/7878 [==============================] - 4s 491us/sample - loss: 0.1207 - accuracy: 0.9454 - val_loss: 0.0869 - val_accuracy: 0.9631
# Epoch 32/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.1283 - accuracy: 0.9411
# Epoch 00032: val_accuracy did not improve from 0.96802
# 7878/7878 [==============================] - 4s 496us/sample - loss: 0.1277 - accuracy: 0.9414 - val_loss: 0.0808 - val_accuracy: 0.9680
# Epoch 33/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.1134 - accuracy: 0.9461
# Epoch 00033: val_accuracy did not improve from 0.96802
# 7878/7878 [==============================] - 4s 486us/sample - loss: 0.1134 - accuracy: 0.9461 - val_loss: 0.0767 - val_accuracy: 0.9680
# Epoch 34/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1151 - accuracy: 0.9476
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.000884736031293869.
#
# Epoch 00034: val_accuracy did not improve from 0.96802
# 7878/7878 [==============================] - 4s 483us/sample - loss: 0.1149 - accuracy: 0.9477 - val_loss: 0.0905 - val_accuracy: 0.9581
# Epoch 35/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1076 - accuracy: 0.9510
# Epoch 00035: val_accuracy improved from 0.96802 to 0.97297, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 6s 817us/sample - loss: 0.1072 - accuracy: 0.9513 - val_loss: 0.0700 - val_accuracy: 0.9730
# Epoch 36/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1200 - accuracy: 0.9459
# Epoch 00036: val_accuracy did not improve from 0.97297
# 7878/7878 [==============================] - 4s 491us/sample - loss: 0.1206 - accuracy: 0.9459 - val_loss: 0.1481 - val_accuracy: 0.9193
# Epoch 37/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1021 - accuracy: 0.9565
# Epoch 00037: val_accuracy improved from 0.97297 to 0.97678, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 861us/sample - loss: 0.1023 - accuracy: 0.9562 - val_loss: 0.0622 - val_accuracy: 0.9768
# Epoch 38/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.1040 - accuracy: 0.9540
# Epoch 00038: val_accuracy did not improve from 0.97678
# 7878/7878 [==============================] - 5s 578us/sample - loss: 0.1038 - accuracy: 0.9538 - val_loss: 0.0848 - val_accuracy: 0.9566
# Epoch 39/80
# 7872/7878 [============================>.] - ETA: 0s - loss: 0.1033 - accuracy: 0.9529
# Epoch 00039: val_accuracy improved from 0.97678 to 0.97982, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 923us/sample - loss: 0.1033 - accuracy: 0.9529 - val_loss: 0.0564 - val_accuracy: 0.9798
# Epoch 40/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1010 - accuracy: 0.9548
# Epoch 00040: val_accuracy did not improve from 0.97982
# 7878/7878 [==============================] - 4s 482us/sample - loss: 0.1011 - accuracy: 0.9548 - val_loss: 0.0606 - val_accuracy: 0.9753
# Epoch 41/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0958 - accuracy: 0.9569
# Epoch 00041: val_accuracy did not improve from 0.97982
# 7878/7878 [==============================] - 4s 485us/sample - loss: 0.0964 - accuracy: 0.9566 - val_loss: 0.0593 - val_accuracy: 0.9779
# Epoch 42/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.1004 - accuracy: 0.9561
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.000849346574395895.
#
# Epoch 00042: val_accuracy did not improve from 0.97982
# 7878/7878 [==============================] - 4s 492us/sample - loss: 0.1008 - accuracy: 0.9561 - val_loss: 0.0624 - val_accuracy: 0.9715
# Epoch 43/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1006 - accuracy: 0.9564
# Epoch 00043: val_accuracy did not improve from 0.97982
# 7878/7878 [==============================] - 4s 485us/sample - loss: 0.1004 - accuracy: 0.9565 - val_loss: 0.1151 - val_accuracy: 0.9421
# Epoch 44/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0927 - accuracy: 0.9615
# Epoch 00044: val_accuracy did not improve from 0.97982
# 7878/7878 [==============================] - 4s 483us/sample - loss: 0.0926 - accuracy: 0.9614 - val_loss: 0.0605 - val_accuracy: 0.9760
# Epoch 45/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.1000 - accuracy: 0.9549
# Epoch 00045: val_accuracy improved from 0.97982 to 0.98173, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 846us/sample - loss: 0.1014 - accuracy: 0.9546 - val_loss: 0.0591 - val_accuracy: 0.9817
# Epoch 46/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0907 - accuracy: 0.9603
# Epoch 00046: val_accuracy did not improve from 0.98173
# 7878/7878 [==============================] - 4s 489us/sample - loss: 0.0905 - accuracy: 0.9605 - val_loss: 0.0994 - val_accuracy: 0.9513
# Epoch 47/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.0918 - accuracy: 0.9617
# Epoch 00047: val_accuracy did not improve from 0.98173
# 7878/7878 [==============================] - 4s 484us/sample - loss: 0.0914 - accuracy: 0.9619 - val_loss: 0.1548 - val_accuracy: 0.9174
# Epoch 48/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0885 - accuracy: 0.9620
# Epoch 00048: val_accuracy improved from 0.98173 to 0.98249, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 6s 823us/sample - loss: 0.0892 - accuracy: 0.9619 - val_loss: 0.0501 - val_accuracy: 0.9825
# Epoch 49/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.0874 - accuracy: 0.9620
# Epoch 00049: val_accuracy did not improve from 0.98249
# 7878/7878 [==============================] - 4s 494us/sample - loss: 0.0875 - accuracy: 0.9617 - val_loss: 0.0633 - val_accuracy: 0.9764
# Epoch 50/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.1055 - accuracy: 0.9597
# Epoch 00050: val_accuracy did not improve from 0.98249
# 7878/7878 [==============================] - 4s 525us/sample - loss: 0.1052 - accuracy: 0.9598 - val_loss: 0.1052 - val_accuracy: 0.9509
# Epoch 51/80
# 7872/7878 [============================>.] - ETA: 0s - loss: 0.0849 - accuracy: 0.9656
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0008153727091848849.
#
# Epoch 00051: val_accuracy did not improve from 0.98249
# 7878/7878 [==============================] - 4s 524us/sample - loss: 0.0849 - accuracy: 0.9656 - val_loss: 0.0767 - val_accuracy: 0.9642
# Epoch 52/80
# 7872/7878 [============================>.] - ETA: 0s - loss: 0.0768 - accuracy: 0.9679
# Epoch 00052: val_accuracy improved from 0.98249 to 0.98401, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 869us/sample - loss: 0.0768 - accuracy: 0.9679 - val_loss: 0.0483 - val_accuracy: 0.9840
# Epoch 53/80
# 7872/7878 [============================>.] - ETA: 0s - loss: 0.0855 - accuracy: 0.9652
# Epoch 00053: val_accuracy improved from 0.98401 to 0.98668, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 840us/sample - loss: 0.0855 - accuracy: 0.9652 - val_loss: 0.0419 - val_accuracy: 0.9867
# Epoch 54/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.0802 - accuracy: 0.9667
# Epoch 00054: val_accuracy did not improve from 0.98668
# 7878/7878 [==============================] - 4s 491us/sample - loss: 0.0798 - accuracy: 0.9670 - val_loss: 0.0687 - val_accuracy: 0.9741
# Epoch 55/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0820 - accuracy: 0.9659
# Epoch 00055: val_accuracy did not improve from 0.98668
# 7878/7878 [==============================] - 4s 498us/sample - loss: 0.0822 - accuracy: 0.9660 - val_loss: 0.1179 - val_accuracy: 0.9433
# Epoch 56/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0682 - accuracy: 0.9719
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0007827577739953995.
#
# Epoch 00056: val_accuracy did not improve from 0.98668
# 7878/7878 [==============================] - 4s 505us/sample - loss: 0.0684 - accuracy: 0.9718 - val_loss: 0.0368 - val_accuracy: 0.9867
# Epoch 57/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0777 - accuracy: 0.9671
# Epoch 00057: val_accuracy did not improve from 0.98668
# 7878/7878 [==============================] - 4s 493us/sample - loss: 0.0777 - accuracy: 0.9671 - val_loss: 0.0551 - val_accuracy: 0.9756
# Epoch 58/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.0711 - accuracy: 0.9730
# Epoch 00058: val_accuracy did not improve from 0.98668
# 7878/7878 [==============================] - 4s 487us/sample - loss: 0.0714 - accuracy: 0.9730 - val_loss: 0.0404 - val_accuracy: 0.9829
# Epoch 59/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.0716 - accuracy: 0.9693
# Epoch 00059: val_accuracy improved from 0.98668 to 0.98782, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 845us/sample - loss: 0.0711 - accuracy: 0.9695 - val_loss: 0.0360 - val_accuracy: 0.9878
# Epoch 60/80
# 7872/7878 [============================>.] - ETA: 0s - loss: 0.0762 - accuracy: 0.9662
# Epoch 00060: val_accuracy did not improve from 0.98782
# 7878/7878 [==============================] - 4s 493us/sample - loss: 0.0762 - accuracy: 0.9662 - val_loss: 0.0547 - val_accuracy: 0.9783
# Epoch 61/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0784 - accuracy: 0.9684
# Epoch 00061: val_accuracy did not improve from 0.98782
# 7878/7878 [==============================] - 4s 493us/sample - loss: 0.0784 - accuracy: 0.9683 - val_loss: 0.0421 - val_accuracy: 0.9863
# Epoch 62/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0689 - accuracy: 0.9707
# Epoch 00062: val_accuracy improved from 0.98782 to 0.99010, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 842us/sample - loss: 0.0689 - accuracy: 0.9706 - val_loss: 0.0361 - val_accuracy: 0.9901
# Epoch 63/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.0697 - accuracy: 0.9718
# Epoch 00063: val_accuracy improved from 0.99010 to 0.99048, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 880us/sample - loss: 0.0697 - accuracy: 0.9717 - val_loss: 0.0336 - val_accuracy: 0.9905
# Epoch 64/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0811 - accuracy: 0.9710
# Epoch 00064: val_accuracy did not improve from 0.99048
# 7878/7878 [==============================] - 4s 488us/sample - loss: 0.0810 - accuracy: 0.9711 - val_loss: 0.0564 - val_accuracy: 0.9737
# Epoch 65/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.0693 - accuracy: 0.9712
# Epoch 00065: val_accuracy did not improve from 0.99048
# 7878/7878 [==============================] - 4s 485us/sample - loss: 0.0688 - accuracy: 0.9713 - val_loss: 0.0306 - val_accuracy: 0.9886
# Epoch 66/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0621 - accuracy: 0.9742
# Epoch 00066: val_accuracy improved from 0.99048 to 0.99086, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 6s 823us/sample - loss: 0.0623 - accuracy: 0.9741 - val_loss: 0.0340 - val_accuracy: 0.9909
# Epoch 67/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.0580 - accuracy: 0.9766
# Epoch 00067: val_accuracy did not improve from 0.99086
# 7878/7878 [==============================] - 4s 488us/sample - loss: 0.0580 - accuracy: 0.9764 - val_loss: 0.0292 - val_accuracy: 0.9874
# Epoch 68/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0659 - accuracy: 0.9737
# Epoch 00068: val_accuracy did not improve from 0.99086
# 7878/7878 [==============================] - 4s 484us/sample - loss: 0.0659 - accuracy: 0.9737 - val_loss: 0.0315 - val_accuracy: 0.9886
# Epoch 69/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0628 - accuracy: 0.9754
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.0007514474540948867.
#
# Epoch 00069: val_accuracy did not improve from 0.99086
# 7878/7878 [==============================] - 4s 479us/sample - loss: 0.0696 - accuracy: 0.9752 - val_loss: 0.0521 - val_accuracy: 0.9775
# Epoch 70/80
# 7872/7878 [============================>.] - ETA: 0s - loss: 0.0722 - accuracy: 0.9686
# Epoch 00070: val_accuracy did not improve from 0.99086
# 7878/7878 [==============================] - 4s 489us/sample - loss: 0.0721 - accuracy: 0.9686 - val_loss: 0.0490 - val_accuracy: 0.9783
# Epoch 71/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0631 - accuracy: 0.9756
# Epoch 00071: val_accuracy did not improve from 0.99086
# 7878/7878 [==============================] - 4s 488us/sample - loss: 0.0629 - accuracy: 0.9758 - val_loss: 0.0344 - val_accuracy: 0.9871
# Epoch 72/80
# 7840/7878 [============================>.] - ETA: 0s - loss: 0.0662 - accuracy: 0.9730
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.0007213895581662655.
#
# Epoch 00072: val_accuracy did not improve from 0.99086
# 7878/7878 [==============================] - 4s 481us/sample - loss: 0.0660 - accuracy: 0.9731 - val_loss: 0.0571 - val_accuracy: 0.9756
# Epoch 73/80
# 7872/7878 [============================>.] - ETA: 0s - loss: 0.0605 - accuracy: 0.9759
# Epoch 00073: val_accuracy improved from 0.99086 to 0.99695, saving model to CNN_ServiceCategory
# 7878/7878 [==============================] - 7s 872us/sample - loss: 0.0604 - accuracy: 0.9759 - val_loss: 0.0193 - val_accuracy: 0.9970
# Epoch 74/80
# 7776/7878 [============================>.] - ETA: 0s - loss: 0.0540 - accuracy: 0.9788
# Epoch 00074: val_accuracy did not improve from 0.99695
# 7878/7878 [==============================] - 4s 505us/sample - loss: 0.0537 - accuracy: 0.9789 - val_loss: 0.0255 - val_accuracy: 0.9951
# Epoch 75/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.0554 - accuracy: 0.9777
# Epoch 00075: val_accuracy did not improve from 0.99695
# 7878/7878 [==============================] - 4s 489us/sample - loss: 0.0551 - accuracy: 0.9778 - val_loss: 0.0172 - val_accuracy: 0.9970
# Epoch 76/80
# 7808/7878 [============================>.] - ETA: 0s - loss: 0.0511 - accuracy: 0.9809
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 0.0006925339624285697.
#
# Epoch 00076: val_accuracy did not improve from 0.99695
# 7878/7878 [==============================] - 4s 538us/sample - loss: 0.0507 - accuracy: 0.9811 - val_loss: 0.0282 - val_accuracy: 0.9920
# Epoch 77/80
# 1664/7878 [=====>........................] - ETA: 2s - loss: 0.0689 - accuracy: 0.9778

# %%
def plot_acc_loss(history, epochs):
    acc = history.history['accuracy']
    loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']
    plt.figure(figsize=(20, 8))
    plt.subplot(121)
    plt.plot(range(1,epochs), acc[1:], label='Train Accuracy')
    plt.plot(range(1,epochs), val_acc[1:], label='Test Accuracy')
    plt.title('Total: ' + str(epochs) + ' runs; '+'ACCURACY', size=18)
    plt.legend()
    plt.grid(True)
    plt.subplot(122)
    plt.plot(range(1,epochs), loss[1:], label='Train Loss')
    plt.plot(range(1,epochs), val_loss[1:], label='Test Loss')
    plt.title('Total: ' + str(epochs) + ' runs; '+'LOSS', size=18)
    plt.legend()
    plt.grid(True)
    plt.show()
    
plot_acc_loss(history, 80)
